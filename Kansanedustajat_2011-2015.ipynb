# %%
import requests
from bs4 import BeautifulSoup

URL = "https://fi.wikipedia.org/wiki/Luettelo_vaalikauden_2011%E2%80%932015_kansanedustajista"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
tabs = soup.find_all("table",{"class":"wikitable sortable"})
ked = tabs[0]
rows = ked.find_all("tr")

# %%
i = 0
names = []
parties = []
for row in rows:
    if i == 0:
        i += 1
        continue
    columns = row.find_all("td")
    #print(columns)
    name = columns[0].find_all("a")[0].get_text()
    name = name.split(" ")[0] + ", " + name.split(" ")[1]
    party = columns[6].find_all("a")[0].get_text()
    print(name, party)
    names.append(name)
    parties.append(party)
    i += 1
    
print(i)
# Out:
# Ahvenjärvi, Sauli kd
# Alanko-Kahiluoto, Outi vihr
# Alatalo, Mikko kesk
# Anttila, Sirkka-Liisa kesk
# Arhinmäki, Paavo vas
# Autto, Heikki kok
# Backman, Jouni sd
# Blomqvist, Thomas r
# Brax, Tuija vihr
# Donner, Jörn r
# Eerola, Juho ps
# Eestilä, Markku kok
# Elomaa, Ritva ps
# Eloranta, Eeva-Johanna sd
# Feldt-Ranta, Maarit sd
# Filatov, Tarja sd
# Gestrin, Christina r
# Grahn-Laasonen, Sanni kok
# Gustafsson, Jukka sd
# Guzenina-Richardson, Maria sd
# Gästgivars, Lars r
# Haapanen, Satu vihr
# Haavisto, Pekka vihr
# Hakkarainen, Teuvo ps
# Halla-aho, Jussi ps
# Harkimo, Leena kok
# Hautala, Lasse kesk
# Heikkilä, Lauri ps
# Heinonen, Timo kok
# Heinäluoma, Eero sd
# Hemmilä, Pertti kok
# Henriksson, Anna-Maja r
# Hiltunen, Rakel sd
# Hirvisaari, James m11
# Holmlund, Anne kok
# Hongisto, Reijo ps
# Huovinen, Susanna sd
# Häkämies, Jyri kok
# Hänninen, Katja vas
# Ihalainen, Lauri sd
# Immonen, Olli ps
# Jalonen, Ari ps
# Jaskari, Harri kok
# Jokinen, Kalle kok
# ...

# %%
import pandas as pd
df = pd.DataFrame(list(zip(names, parties)),
               columns =['name', 'party'])

df.to_csv("kansanedustajat_2011-2015.csv")
